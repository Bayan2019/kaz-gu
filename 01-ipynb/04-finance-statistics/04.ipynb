# %%
import math

# %%
math.log(40)+(0.18-(0.2)**2/2)*0.3
# Out:
# 3.7368794541139363

# %%
math.sqrt(0.2**2 *0.3)
# Out:
# 0.10954451150103323

# %%
3.7368794541139363- 2.5758*0.10954451150103323
# Out:
# 3.454714701389575

# %%
3.7368794541139363+ 2.5758*0.10954451150103323
# Out:
# 4.019044206838298

# %%
print(math.exp(3.7368794541139363- 2.5758*0.10954451150103323), math.exp(3.7368794541139363+ 2.5758*0.10954451150103323))
# Out:
# 31.649257904800745 55.64789252525301

# %%
math.exp(3.45664)
# Out:
# 31.71025087306377

# %%
math.log(20)+(1.5-(1.2)**2/2)
# Out:
# 3.7757322735539907

# %%
print(math.exp(math.log(20)+(1.5-(1.2)**2/2)-1.96*1.2), math.exp(math.log(20)+(1.5-(1.2)**2/2)+1.96*1.2))
# Out:
# 4.152590156108324 458.395465599973

# %%
print(math.exp(math.log(40)+(0.16-(0.2)**2/2)*0.5-1.96*0.2*math.sqrt(0.5)), math.exp(math.log(40)+(0.16-(0.2)**2/2)*0.5+1.96*0.2*math.sqrt(0.5)))
# Out:
# 32.51474230558975 56.603188205344175

# %%
0.2*math.sqrt(0.5)
# Out:
# 0.14142135623730953
